# %%
import netCDF4 as nc
PATH = {}
PATH["weather"] = "data/weather/"

# %%
PATH = {}
PATH["weather"] = "data/weather/"
ds = nc.Dataset(PATH["weather"]+"orig_CO_2019_ym.nc")

# %%
ds
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_64BIT_OFFSET data model, file format NETCDF3):
#     CDI: Climate Data Interface version 1.8.0rc2 (http://mpimet.mpg.de/cdi)
#     Conventions: None
#     history: Tue Oct 06 09:47:58 2020: cdo merge lonlat.nc orig_CO_2019_b.nc orig_CO_2019_ym.nc
# Tue Oct 06 09:41:09 2020: cdo merge lon.nc lat.nc lonlat.nc
# Tue Oct 06 09:41:04 2020: cdo selvar,lon CO_201901_lonlat.nc lon.nc
# Thu Sep 24 09:27:16 2020: cdo merge lonlat.nc CO_201901.nc CO_201901_lonlat.nc
# Thu Sep 24 09:20:39 2020: cdo merge lon.nc lat.nc lonlat.nc
# Thu Sep 24 09:19:10 2020: cdo selvar,lon out.2019011300_2019011400_eves.nc lon.nc
# File /home/ferenczi/chimere2017/BIGFILES/OUTPUTS/HUN1/eves/out.2019011300_2019011400_eves.nc was generated on Thu Jan  2 11:59:36 2020 by ferenczi on ucs02.met.hu
#     Title: CHIMERE SUITE
#     Sub-title: Hourly output concentrations file
#     Chimere_type: out
#     Generating_process: Generated by chimere
#     Domain: HUN1
# ...

# %%
print(ds.__dict__)
# Out:
# {'CDI': 'Climate Data Interface version 1.8.0rc2 (http://mpimet.mpg.de/cdi)', 'Conventions': 'None', 'history': 'Tue Oct 06 09:47:58 2020: cdo merge lonlat.nc orig_CO_2019_b.nc orig_CO_2019_ym.nc\nTue Oct 06 09:41:09 2020: cdo merge lon.nc lat.nc lonlat.nc\nTue Oct 06 09:41:04 2020: cdo selvar,lon CO_201901_lonlat.nc lon.nc\nThu Sep 24 09:27:16 2020: cdo merge lonlat.nc CO_201901.nc CO_201901_lonlat.nc\nThu Sep 24 09:20:39 2020: cdo merge lon.nc lat.nc lonlat.nc\nThu Sep 24 09:19:10 2020: cdo selvar,lon out.2019011300_2019011400_eves.nc lon.nc\nFile /home/ferenczi/chimere2017/BIGFILES/OUTPUTS/HUN1/eves/out.2019011300_2019011400_eves.nc was generated on Thu Jan  2 11:59:36 2020 by ferenczi on ucs02.met.hu', 'Title': 'CHIMERE SUITE', 'Sub-title': 'Hourly output concentrations file', 'Chimere_type': 'out', 'Generating_process': 'Generated by chimere', 'Domain': 'HUN1', 'Chimere_version': 'chimere2017', 'CDO': 'Climate Data Operators version 1.8.0rc2 (http://mpimet.mpg.de/cdo)'}

# %%
for dim in ds.dimensions.values():
    print(dim)
# Out:
# <class 'netCDF4._netCDF4.Dimension'>: name = 'west_east', size = 111
# <class 'netCDF4._netCDF4.Dimension'>: name = 'south_north', size = 51
# <class 'netCDF4._netCDF4.Dimension'>: name = 'lev', size = 1
# <class 'netCDF4._netCDF4.Dimension'> (unlimited): name = 'Times', size = 1
# <class 'netCDF4._netCDF4.Dimension'>: name = 'bnds', size = 2

# %%
for var in ds.variables.values():
    print(var)
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 lev(lev)
#     long_name: generic
#     units: level
#     axis: Z
# unlimited dimensions:
# current shape = (1,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 Times(Times)
#     standard_name: time
#     long_name: WRF-style Times
#     bounds: Times_bnds
#     units: day as %Y%m%d.%f
#     calendar: proleptic_gregorian
#     axis: T
# unlimited dimensions: Times
# current shape = (1,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 Times_bnds(Times, bnds)
# unlimited dimensions: Times
# current shape = (1, 2)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 lon(south_north, west_east)
#     long_name: Longitude
#     units: degrees_east
# unlimited dimensions:
# current shape = (51, 111)
# filling on, default _FillValue of 9.969209968386869e+36 used
# ...

# %%
print(ds['lat'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 lat(south_north, west_east)
#     long_name: Latitude
#     units: degrees_north
# unlimited dimensions:
# current shape = (51, 111)
# filling on, default _FillValue of 9.969209968386869e+36 used

# %%
ds['lat'][:][2]
# Out:
# masked_array(data=[45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2,
#                    45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2,
#                    45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2,
#                    45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2,
#                    45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2,
#                    45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2,
#                    45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2,
#                    45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2,
#                    45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2,
#                    45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2,
#                    45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2,
#                    45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2, 45.2,
#                    45.2, 45.2, 45.2],
#              mask=False,
#        fill_value=1e+20)

# %%
ds['lon'][:][0]
# Out:
# masked_array(data=[14. , 14.1, 14.2, 14.3, 14.4, 14.5, 14.6, 14.7, 14.8,
#                    14.9, 15. , 15.1, 15.2, 15.3, 15.4, 15.5, 15.6, 15.7,
#                    15.8, 15.9, 16. , 16.1, 16.2, 16.3, 16.4, 16.5, 16.6,
#                    16.7, 16.8, 16.9, 17. , 17.1, 17.2, 17.3, 17.4, 17.5,
#                    17.6, 17.7, 17.8, 17.9, 18. , 18.1, 18.2, 18.3, 18.4,
#                    18.5, 18.6, 18.7, 18.8, 18.9, 19. , 19.1, 19.2, 19.3,
#                    19.4, 19.5, 19.6, 19.7, 19.8, 19.9, 20. , 20.1, 20.2,
#                    20.3, 20.4, 20.5, 20.6, 20.7, 20.8, 20.9, 21. , 21.1,
#                    21.2, 21.3, 21.4, 21.5, 21.6, 21.7, 21.8, 21.9, 22. ,
#                    22.1, 22.2, 22.3, 22.4, 22.5, 22.6, 22.7, 22.8, 22.9,
#                    23. , 23.1, 23.2, 23.3, 23.4, 23.5, 23.6, 23.7, 23.8,
#                    23.9, 24. , 24.1, 24.2, 24.3, 24.4, 24.5, 24.6, 24.7,
#                    24.8, 24.9, 25. ],
#              mask=False,
#        fill_value=1e+20)

# %%
# or as micrograms per kilogram (µg/kg), which is equal to parts per  billion (ppb)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ds['CO'][:]
# Out:
# masked_array(
#   data=[[[[173.78815, 171.01495, 170.07361, ..., 156.20235, 157.4395 ,
#            158.64876],
#           [171.58084, 171.44412, 169.49619, ..., 157.00279, 157.59659,
#            158.34425],
#           [170.87593, 170.359  , 170.70117, ..., 155.94162, 156.68718,
#            157.48143],
#           ...,
#           [167.01991, 173.60849, 173.03142, ..., 154.76538, 156.80067,
#            156.98381],
#           [174.37508, 178.83408, 183.96101, ..., 157.10162, 157.27802,
#            157.77538],
#           [177.89098, 184.3785 , 185.51108, ..., 158.45943, 158.33727,
#            158.43718]]]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)

# %%
ds = nc.Dataset(PATH["weather"]+"orig_O3_2021_ym.nc")

# %%
ds['O3'][:]
# Out:
# masked_array(
#   data=[[[[85.052956, 86.1222  , 88.404106, ..., 81.41757 , 80.2739  ,
#            79.5555  ],
#           [84.767204, 83.70357 , 85.44078 , ..., 82.041245, 81.18306 ,
#            80.18013 ],
#           [82.95715 , 82.90793 , 82.795265, ..., 81.76555 , 81.0932  ,
#            80.81292 ],
#           ...,
#           [73.10075 , 74.499565, 76.171486, ..., 76.13177 , 74.503265,
#            73.53378 ],
#           [69.4964  , 69.53167 , 73.923706, ..., 72.53056 , 72.678535,
#            73.064896],
#           [69.4712  , 67.89324 , 72.61279 , ..., 71.01874 , 71.36046 ,
#            71.53265 ]]]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)

# %%
for var in ds.variables.values():
    print(var)
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 lev(lev)
#     long_name: generic
#     units: level
#     axis: Z
# unlimited dimensions:
# current shape = (1,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 Times(Times)
#     standard_name: time
#     long_name: WRF-style Times
#     bounds: Times_bnds
#     units: day as %Y%m%d.%f
#     calendar: proleptic_gregorian
#     axis: T
# unlimited dimensions: Times
# current shape = (1,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 Times_bnds(Times, bnds)
# unlimited dimensions: Times
# current shape = (1, 2)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 lon(south_north, west_east)
#     long_name: Longitude
#     units: degrees_east
# unlimited dimensions:
# current shape = (51, 111)
# filling on, default _FillValue of 9.969209968386869e+36 used
# ...
