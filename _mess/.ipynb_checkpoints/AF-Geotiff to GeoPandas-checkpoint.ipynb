# %%
import main as m
import rasterio as rs
from rasterio.plot import show
inp = 'RCM_ta_20112040_ann_p_1_HU.tif'
inp = 'OBS_ta_19912020_JJA_o_0_HU.tif'
inp = 'too-hot-days-19912020_ann_o_0_HU.tif'
#fp = r'inp'
img = rs.open(inp)
show(img)
# Out:
# C:\Users\MUSIC\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\colors.py:715: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N
# <AxesSubplot: >

# %%
### CHATGPT
import rasterio
import geopandas as gpd
from rasterio.features import shapes

# Load the GeoTIFF file into a Rasterio dataset object
with rasterio.open(inp) as src:
    dataset = src.read(1)
    transform = src.transform
    crs = src.crs

# Extract the values from the raster as a list of shapes and values
shapes = shapes(dataset, transform=transform)

shapeRaw = []
for i in shapes:
    shapeRaw.append(i)

# Convert the list of shapes and values to a GeoPandas GeoDataFrame
# gdf = gpd.GeoDataFrame.from_features(shapes, crs=crs)
# gdf = gpd.GeoDataFrame.from_features(shapeRaw, crs=crs)

# Drop any missing or invalid values
# gdf.dropna(inplace=True)

# y is a value
# x is a polygon
polygons = []
values = []
data = []
for x,y in shapeRaw:
    l = []
    l.append(x['coordinates'])
    #print(i['coordinates'])
    #print(i['type'])
    l.append(y)
    data.append(l)
df = m.pd.DataFrame(data, columns=['geometry', 'value'])
gdf = gpd.GeoDataFrame(df, crs=crs, geometry=[m.Polygon(x[0]) for x in df['geometry']])
t = gdf.to_crs({'init': 'epsg:4326'}) #4326 works since https://epsg.io/?q=4326
t = t[t.value > min(t.value)]
# Out:
# C:\Users\MUSIC\AppData\Local\Programs\Python\Python310\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
t
# Out:
#                                                geometry      value
# 0     POLYGON ((20.53742 48.65000, 20.53742 48.56981...   8.400000
# 1     POLYGON ((20.65870 48.65000, 20.65870 48.56981...  17.070000
# 2     POLYGON ((20.77998 48.65000, 20.77998 48.56981...  19.530001
# 4     POLYGON ((21.26511 48.65000, 21.26511 48.56981...  19.969999
# 5     POLYGON ((21.38639 48.65000, 21.38639 48.56981...   5.230000
# ...                                                 ...        ...
# 999   POLYGON ((18.35435 45.85190, 18.35435 45.76736...  36.000000
# 1000  POLYGON ((18.47563 45.85190, 18.47563 45.76736...  35.900002
# 1001  POLYGON ((18.23307 45.76736, 18.23307 45.68269...  35.730000
# 1002  POLYGON ((18.35435 45.76736, 18.35435 45.68269...  35.930000
# 1003  POLYGON ((18.47563 45.76736, 18.47563 45.68269...  36.400002
#
# [1000 rows x 2 columns]

# %%
import folium
import matplotlib
import mapclassify
t.explore("value", cmap="YlGn")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0dd8bfb74e45ea7fbb80057ceb16f497 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0dd8bfb74e45ea7fbb80057ceb16f497&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0dd8bfb74e45ea7fbb80057ceb16f497 = L.map(
#                 &quot;map_0dd8bfb74e45ea7fbb80057ceb16f497&quot;,
#                 {
#                     center: [47.16634493397443, 19.506524075505833],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0dd8bfb74e45ea7fbb80057ceb16f497);
#
#
#
#
#
#             var tile_layer_03142c8efe78d0dc53038f91a9bf81a6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0dd8bfb74e45ea7fbb80057ceb16f497);
#
#
#             map_0dd8bfb74e45ea7fbb80057ceb16f497.fitBounds(
#                 [[45.682689867948866, 16.05], [48.65, 22.963048151011666]],
#                 {}
#             );
#
#
#         function geo_json_0cdd07f94ae23f4fab643ee806367c86_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#e7f6ad&quot;, &quot;fillColor&quot;: &quot;#e7f6ad&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;20&quot;: case &quot;55&quot;: case &quot;127&quot;:
#                     return {&quot;color&quot;: &quot;#a2d88a&quot;, &quot;fillColor&quot;: &quot;#a2d88a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;13&quot;: case &quot;19&quot;: case &quot;705&quot;:
#                     return {&quot;color&quot;: &quot;#8bce81&quot;, &quot;fillColor&quot;: &quot;#8bce81&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;38&quot;: case &quot;56&quot;: case &quot;356&quot;: case &quot;702&quot;: case &quot;745&quot;:
#                     return {&quot;color&quot;: &quot;#86cc7f&quot;, &quot;fillColor&quot;: &quot;#86cc7f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#f7fcbc&quot;, &quot;fillColor&quot;: &quot;#f7fcbc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#f5fbb8&quot;, &quot;fillColor&quot;: &quot;#f5fbb8&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;132&quot;:
#                     return {&quot;color&quot;: &quot;#e5f5ac&quot;, &quot;fillColor&quot;: &quot;#e5f5ac&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;40&quot;: case &quot;171&quot;: case &quot;304&quot;: case &quot;392&quot;: case &quot;527&quot;: case &quot;622&quot;: case &quot;829&quot;: case &quot;904&quot;:
#                     return {&quot;color&quot;: &quot;#68be71&quot;, &quot;fillColor&quot;: &quot;#68be71&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;: case &quot;129&quot;: case &quot;613&quot;: case &quot;909&quot;:
#                     return {&quot;color&quot;: &quot;#9fd788&quot;, &quot;fillColor&quot;: &quot;#9fd788&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;64&quot;: case &quot;910&quot;:
#                     return {&quot;color&quot;: &quot;#b3e091&quot;, &quot;fillColor&quot;: &quot;#b3e091&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;426&quot;:
#                     return {&quot;color&quot;: &quot;#c8e99b&quot;, &quot;fillColor&quot;: &quot;#c8e99b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;: case &quot;122&quot;: case &quot;163&quot;: case &quot;396&quot;:
#                     return {&quot;color&quot;: &quot;#8ed082&quot;, &quot;fillColor&quot;: &quot;#8ed082&quot;, &quot;fillOpacity&quot;: 0.5, &qu
