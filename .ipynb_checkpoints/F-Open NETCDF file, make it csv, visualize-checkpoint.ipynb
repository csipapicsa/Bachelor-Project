# %%
import main as m
# reload
import importlib as i
# reload if it is neccesarry i.reload(m)

# %%
PATH = {}
PATH["weather"] = "data/weather/"
DS = m.xr.open_dataset(PATH["weather"]+"orig_CO_2019_ym.nc")

# write to csv
# DS.to_dataframe().to_csv("output_filename.csv")
# read in
df = DS.to_dataframe()
df = m.gpd.GeoDataFrame(
    df, geometry=m.gpd.points_from_xy(df.lon, df.lat))

# convert values
df["lon"] = df["lon"].astype(float)
df["lat"] = df["lat"].astype(float)
# double conversation needs
df.CO = df.CO.astype(float).astype(int)
# important! 
df.crs = "EPSG:23700" #Hungary
#print(df.head())
# filter, since there are duplications
df = df[df["Times_bnds"] == 20190101.0]
###########################################
###########################################
# filter focusing on Hungary
df = df[df["lon"] < 23.02]
df = df[df["lon"] > 16.072]
df = df[df["lat"] > 45.699]
df = df[df["lat"] < 48.7]

# since there are only points, expand them to square
for key in df.index:
    df.geometry[key] = m.Polygon(((df.lon[key]-0.1, df.lat[key]),
                (df.lon[key], df.lat[key]),
               (df.lon[key], df.lat[key]+0.1),
           
               (df.lon[key]-0.1, df.lat[key]+0.1)))

# %% [markdown]
# ### Filtering

# %% [markdown]
# A simple filter for CO level and map areas

# %%
print("Choose between ", min(df.CO), " ", max(df.CO)) 
COLEVELEXCEED = int(input())
#print(COLEVELEXCEED)
# set a mask for developing reasons
df.crs = "epsg:4326"
dfF = df[df.CO > COLEVELEXCEED]
#dfF = df[df.CO > 150]

# get boudaries
## boundaries
boundary1 = m.gpd.GeoSeries(m.unary_union(dfF.geometry))
# plot
m.multiPolygonVisualizer(boundary1)
# Out:
# Choose between  145   434
# 160
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8baeb05e442714dffda52330f9f31fca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8baeb05e442714dffda52330f9f31fca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8baeb05e442714dffda52330f9f31fca = L.map(
#                 &quot;map_8baeb05e442714dffda52330f9f31fca&quot;,
#                 {
#                     center: [47.762196497129665, 19.6742448729209],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4b13951ec5e7626159a296714467bfb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8baeb05e442714dffda52330f9f31fca);
#
#
#         function geo_json_44df5cf7ab2af17db493375f7dafbbe7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;blue&quot;, &quot;weight&quot;: 0};
#             }
#         }
#
#         function geo_json_44df5cf7ab2af17db493375f7dafbbe7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_44df5cf7ab2af17db493375f7dafbbe7 = L.geoJson(null, {
#                 onEachFeature: geo_json_44df5cf7ab2af17db493375f7dafbbe7_onEachFeature,
#
#                 style: geo_json_44df5cf7ab2af17db493375f7dafbbe7_styler,
#         });
#
#         function geo_json_44df5cf7ab2af17db493375f7dafbbe7_add (data) {
#             geo_json_44df5cf7ab2af17db493375f7dafbbe7
#                 .addData(data)
#                 .addTo(map_8baeb05e442714dffda52330f9f31fca);
#         }
#             geo_json_44df5cf7ab2af17db493375f7dafbbe7_add({&quot;bbox&quot;: [16.0, 45.7, 22.9, 48.7], &quot;features&quot;: [{&quot;bbox&quot;: [16.0, 45.7, 22.9, 48.7], &quot;geometry&quot;: {&quot;coordinates&quot;: [[
5], [16.9, 46.5], [16.9, 46.6]]], [[[18.0, 47.2], [18.1, 47.2], [18.1, 47.1], [18.0, 47.1], [18.0, 47.2]]], [[[16.5, 47.300000000000004], [16.6, 47.300000000000004], [16.6, 47.2], [16.5, 47.2], [16.5, 47.300000000000004]]], [[[17.0, 48.1], [17.0, 48.2], [17.0, 48.300000000000004], [17.1, 48.300000000000004], [17.1, 48.2], [17.1, 48.1], [17.0, 48.1]]], [[[18.4, 46.4], [18.5, 46.4], [18.5, 46.3], [18.4, 46.3], [18.4, 46.4]]], [[[18.7, 46.5], [18.8, 46.5], [18.8, 46.4], [18.7, 46.4], [18.7, 46.5]]], [[[18.9, 46.6], [19.0, 46.6], [19.0, 46.5], [18.9, 46.5], [18.9, 46.6]]], [[[18.599999999999998, 46.9], [18.5, 46.9], [18.5, 47.0], [18.599999999999998, 47.0], [18

# %%
print(df.head())
df.explore("CO", cmap="YlGn")
# Out:
#                                              Times_bnds   lon   lat   CO  \
# lev Times        bnds south_north west_east
# 1.0 2.019070e+07 0    7           21         20190101.0  16.1  45.7  178
#                                   22         20190101.0  16.2  45.7  173
#                                   23         20190101.0  16.3  45.7  168
#                                   24         20190101.0  16.4  45.7  167
#                                   25         20190101.0  16.5  45.7  165
#
#                                                                                       geometry
# lev Times        bnds south_north west_east
# 1.0 2.019070e+07 0    7           21         POLYGON ((16.00000 45.70000, 16.10000 45.70000...
#                                   22         POLYGON ((16.10000 45.70000, 16.20000 45.70000...
#                                   23         POLYGON ((16.20000 45.70000, 16.30000 45.70000...
#                                   24         POLYGON ((16.30000 45.70000, 16.40000 45.70000...
#                                   25         POLYGON ((16.40000 45.70000, 16.50000 45.70000...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5060e85acb8b8e68af80040770ec788c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5060e85acb8b8e68af80040770ec788c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5060e85acb8b8e68af80040770ec788c = L.map(
#                 &quot;map_5060e85acb8b8e68af80040770ec788c&quot;,
#                 {
#                     center: [47.2, 19.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5060e85acb8b8e68af80040770ec788c);
#
#
#
#
#
#             var tile_layer_beabc8b91d27b167d1f975529b67792f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5060e85acb8b8e68af80040770ec788c);
#
#
#             map_5060e85acb8b8e68af80040770ec788c.fitBounds(
#                 [[45.7, 16.0], [48.7, 23.0]],
#                 {}
#             );
#
#
#         function geo_json_19200f4cd30f6bbd672140daac2a8e53_styler(feature) {
#             switch(feature.id) {
#                 case &quot;(1.0, 20190701.229166668, 0, 7, 21)&quot;: case &quot;(1.0, 20190701.229166668, 0, 26, 53)&quot;: case &quot;(1.0, 20190701.229166668, 0, 32, 69)&quot;: case &quot;(1.0, 20190701.229166668, 0, 33, 70)&quot;: case &quot;(1.0, 20190701.229166668, 0, 34, 24)&quot;: case &quot;(1.0, 20190701.229166668, 0, 36, 75)&quot;:
#                     return {&quot;color&quot;: &quot;#f8fcbd&quot;, &quot;fillColor&quot;: &quot;#f8fcbd&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;(1.0, 20190701.229166668, 0, 7, 22)&quot;: case &quot;(1.0, 20190701.229166668, 0, 13, 61)&quot;: case &quot;(1.0, 20190701.229166668, 0, 17, 71)&quot;: case &quot;(1.0, 20190701.229166668, 0, 24, 54)&quot;: case &quot;(1.0, 20190701.229166668, 0, 28, 23)&quot;: case &quot;(1.0, 20190701.229166668, 0, 33, 21)&quot;: case &quot;(1.0, 20190701.229166668, 0, 34, 22)&quot;: case &quot;(1.0, 20190701.229166668, 0, 34, 69)&quot;:
#                     return {&quot;color&quot;: &quot;#f9fdc4&quot;, &quot;fillColor&quot;: &quot;#f9fdc4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;(1.0, 20190701.229166668, 0, 7, 23)&quot;: case &quot;(1.0, 20190701.229166668, 0, 11, 23)&quot;: case &quot;(1.0, 20190701.229166668, 0, 11, 42)&quot;: case &quot;(1.0, 20190701.229166668, 0, 12, 22)&quot;: case &quot;(1.0, 20190701.229166668, 0, 19, 48)&quot;: case &quot;(1.0, 20190701.229166668, 0, 19, 50)&quot;: case &quot;(1.0, 20190701.229166668, 0, 19, 56)&quot;: case &quot;(1.0, 20190701.229166668, 0, 24, 55)&quot;: case &quot;(1.0, 20190701.229166668, 0, 24, 56)&quot;: case &quot;(1.0, 20190701.229166668, 0, 24, 57)&quot;: case &quot;(1.0, 20190701.229166668, 0, 25, 48)&quot;: case &quot;(1.0, 20190701.229166668, 0, 26, 48)&quot;: case &quot;(1.0, 20190701.229166668, 0, 26, 55)&quot;: case &quot;(1.0, 20190701.229166668, 0, 26, 56)&quot;: case &quot;(1.0, 20190701.229166668, 0, 26, 77)&quot;: case &quot;(1.0, 20190701.229166668, 0, 27, 22)&quot;: case &quot;(1.0, 20190701.229166668, 0, 27, 54)&quot;: case &quot;(1.0, 20190701.229166668, 0, 27, 57)&quot;: case &quot;(1.0, 20190701.229166668, 0, 27, 76)&quot;: case &quot;(1.0, 20190701.229166668, 0, 28, 21)&quot;: case &quot;(1.0, 20190701.229166668, 0, 28, 50)&quot;: case &quot;(1.0, 20190701.229166668, 0, 30, 26)&quot;: case &quot;(1.0, 20190701.229166668, 0, 32, 63)&quot;: case &quot;(1.0, 20190701.229166668, 0, 32, 65)&quot;: case &quot;(1.0, 20190701.229166668, 0, 34, 21)&quot;: case &quot;(1.0, 20190701.229166668, 0, 34, 26)&quot;: case &quot;(1.0, 20190701.229166668, 0, 34, 66)&quot;: case &quot;(1.0, 20190701.229166668, 0, 35, 67)&quot;:
#                     return {&quot;color&quot;: &quot;#fafdc9&quot;, &quot;fillColor&quot;: &quot;#fafdc9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;(1.0, 20190701.229166668, 0, 7, 24)&quot;: case &quot;(1.0, 20190701.229166668, 0, 7, 72)&quot;: case &quot;(1.0, 20190701.229166668, 0, 8, 24)&quot;: case &quot;(1.0, 20190701.229166668, 0, 10, 23)&quot;: case &quot;(1.0,

# %%
def airQualityAverager(AIRQUALITYFILELIST, MEASURE):
    return df
